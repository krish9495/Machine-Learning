# %%
import pandas as pd
import numpy as np

# %%
from sklearn.impute import SimpleImputer,KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv(r'D:\100 Days machine learning\Multivariate-KNN imputer day 39\train.csv',usecols=['Age','Pclass','Fare','Survived',])

# %%
df.head()
# Out:
#    Survived  Pclass   Age     Fare
# 0         0       3  22.0   7.2500
# 1         1       1  38.0  71.2833
# 2         1       3  26.0   7.9250
# 3         1       1  35.0  53.1000
# 4         0       3  35.0   8.0500

# %%
df.isnull().mean()*100
# Out:
# Survived     0.00000
# Pclass       0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.head()
# Out:
#      Pclass   Age     Fare
# 30        1  40.0  27.7208
# 10        3   4.0  16.7000
# 873       3  47.0   9.0000
# 182       3   9.0  31.3875
# 876       3  20.0   9.8458

# %%
knn=KNNImputer(n_neighbors=3,weights='distance')

# %%
X_train_trf=knn.fit_transform(X_train)
X_test_trf=knn.transform(X_test)

# %%
pd.DataFrame(X_train_trf,columns=X_train.columns)
# Out:
#      Pclass        Age      Fare
# 0       1.0  40.000000   27.7208
# 1       3.0   4.000000   16.7000
# 2       3.0  47.000000    9.0000
# 3       3.0   9.000000   31.3875
# 4       3.0  20.000000    9.8458
# ..      ...        ...       ...
# 707     3.0  30.000000    8.6625
# 708     3.0  26.959410    8.7125
# 709     1.0  71.000000   49.5042
# 710     1.0  32.666667  221.7792
# 711     1.0  49.762895   25.9250
#
# [712 rows x 3 columns]

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train_trf,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_test_trf)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7039106145251397

# %%
si=SimpleImputer()

# %%
X_train_trf2=si.fit_transform(X_train)

# %%
X_test_trf2=si.transform(X_test)

# %%
lr.fit(X_train_trf2,y_train)
# Out:
# LogisticRegression()

# %%
y_pred2=lr.predict(X_test_trf2)

# %%
accuracy_score(y_pred2,y_test)
# Out:
# 0.6927374301675978
