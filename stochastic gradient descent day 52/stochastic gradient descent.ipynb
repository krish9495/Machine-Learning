# %%
from sklearn.datasets import load_diabetes

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import numpy as np

# %%
X,y=load_diabetes(return_X_y=True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
lr.intercept_
# Out:
# np.float64(151.88331005254167)

# %%
y_pred=lr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
class SGDRegressor:
    def __init__(self,learning_rate=0.1,epochs=100):
        self.coef=None
        self.intercept=None
        self.lr=learning_rate
        self.epoch=epochs

    def fit(self,X_train,y_train):
        self.intercept=0
        self.coef=np.ones(X_train.shape[1])
        for i in range(self.epoch):
            for j in range (X_train.shape[0]):
                idx=np.random.randint(0,X_train.shape[0])
                
                y_hat=np.dot(X_train[idx],self.coef)+self.intercept
                
                intercept_der = -2* (y_train[idx]-y_hat)
                self.intercept=self.intercept - (self.lr* intercept_der)

                coef_der= -2 * np.dot((y_train[idx]-y_hat),X_train[idx])
                self.coef=self.coef - (self.lr * coef_der)

        print(self.coef,self.intercept)


    def predict(self,X_test):
        return np.dot(X_test,self.coef)+ self.intercept

# %%
sgd=SGDRegressor(learning_rate=0.1,epochs=20)

# %%
sgd.fit(X_train,y_train)
# Out:
# [  20.36623447 -182.09650075  535.10478083  342.64763107  -64.10352216
#  -161.44783318 -181.29913641   90.38172161  492.80476952   95.90926204] 147.44455288521712

# %%
y_pred=sgd.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4372574659563363

# %%
from sklearn.linear_model import SGDRegressor

# %%
reg=SGDRegressor(max_iter=100,learning_rate='constant',eta0=0.01)

# %%
reg.fit(X_train,y_train)
# Out:
# C:\Users\avani\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDRegressor(learning_rate='constant', max_iter=100)

# %%
y_pred=reg.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.43310467129823804
